# %% [markdown]
# # **Instituto Tecnologico de Monterrey**
# # **Maestría en Inteligencia Artificial Aplicada**
# # **Curso: Pruebas de Software y aseguramiento de la Calidad**
# # **Clave: TC4017.10**
# ## Profesor Títular: Dr. Gerardo Padilla Zárate
# ## Profesora Asistente: Mtra. Viridiana Rodríguez González
# ## Estudiante: Francisco Javier Ramírez Arias
# ## Matrícula: A01316379
#
# ##Actividad: Actividad 5.2
# ##Ejercicio de Programación #2
# ##Descripción: Cálculo de ventas.

# %%
#!/usr/bin/env python3

# %%writefile computeSales.py



import sys
import json
import time


def load_json_file(file_path):

    try:
        with open(file_path, "r", encoding="utf-8") as file:
            return json.load(file)
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except json.JSONDecodeError as error:
        print(f"Error: Invalid JSON format in '{file_path}': {error}")
        return None


def build_price_dictionary(price_catalogue):

    price_dict = {}

    for item in price_catalogue:
        try:
            title = item["title"]
            price = float(item["price"])
            price_dict[title] = price
        except (KeyError, ValueError, TypeError):
            print(f"Warning: Invalid product entry ignored: {item}")

    return price_dict


def compute_total_sales(price_dict, sales_record):

    total_cost = 0.0
    detailed_lines = []

    for entry in sales_record:
        try:
            product = entry["Product"]
            quantity = int(entry["Quantity"])

            if product not in price_dict:
                print(f"Warning: Product '{product}' not found in catalogue.")
                continue

            if quantity < 0:
                print(f"Warning: Negative quantity ignored: {entry}")
                continue

            unit_price = price_dict[product]
            subtotal = unit_price * quantity
            total_cost += subtotal

            detailed_lines.append(
                f"Product: {product:<30} "
                f"Qty: {quantity:<5} "
                f"Unit Price: ${unit_price:<8.2f} "
                f"Subtotal: ${subtotal:.2f}"
            )

        except (KeyError, ValueError, TypeError):
            print(f"Warning: Invalid sale entry ignored: {entry}")

    return total_cost, detailed_lines


def write_results(report_lines):

    with open("SalesResults.txt", "w", encoding="utf-8") as file:
        for line in report_lines:
            file.write(line + "\n")


def main():

    start_time = time.perf_counter()

    if len(sys.argv) != 3:
        print(
            "Usage: python computeSales.py "
            "priceCatalogue.json salesRecord.json"
        )
        sys.exit(1)

    price_file = sys.argv[1]
    sales_file = sys.argv[2]

    price_catalogue = load_json_file(price_file)
    sales_record = load_json_file(sales_file)

    if price_catalogue is None or sales_record is None:
        sys.exit(1)

    price_dict = build_price_dictionary(price_catalogue)

    total_cost, detailed_lines = compute_total_sales(
        price_dict,
        sales_record,
    )

    end_time = time.perf_counter()
    elapsed_time = end_time - start_time

    report = []
    report.append("==== COMPANY SALES REPORT ====")
    report.append("")
    report.extend(detailed_lines)
    report.append("")
    report.append(f"TOTAL COMPANY SALES: ${total_cost:.2f}")
    report.append(
        f"Execution Time (seconds): {elapsed_time:.6f}"
    )

    for line in report:
        print(line)

    write_results(report)


if __name__ == "__main__":
    main()
# Out:
# Overwriting computeSales.py

# %% [markdown]
# ## Cálculo de ventas (archivo): TC1.Sales.json

# %%
# !python computeSales.py TC1.ProductList.json TC1.Sales.json
# Out:
# ==== COMPANY SALES REPORT ====
#
# Product: Rustic breakfast               Qty: 1     Unit Price: $21.32    Subtotal: $21.32
# Product: Sandwich with salad            Qty: 2     Unit Price: $22.48    Subtotal: $44.96
# Product: Raw legums                     Qty: 1     Unit Price: $17.11    Subtotal: $17.11
# Product: Fresh stawberry                Qty: 1     Unit Price: $28.59    Subtotal: $28.59
# Product: Pears juice                    Qty: 2     Unit Price: $19.49    Subtotal: $38.98
# Product: Green smoothie                 Qty: 3     Unit Price: $17.68    Subtotal: $53.04
# Product: Cuban sandwiche                Qty: 2     Unit Price: $18.50    Subtotal: $37.00
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Tomatoes                       Qty: 1     Unit Price: $26.03    Subtotal: $26.03
# Product: Plums                          Qty: 1     Unit Price: $19.18    Subtotal: $19.18
# Product: Fresh blueberries              Qty: 2     Unit Price: $21.01    Subtotal: $42.02
# Product: Green smoothie                 Qty: 2     Unit Price: $17.68    Subtotal: $35.36
# Product: Corn                           Qty: 3     Unit Price: $13.55    Subtotal: $40.65
# Product: French fries                   Qty: 1     Unit Price: $18.32    Subtotal: $18.32
# Product: Ground beef meat burger        Qty: 1     Unit Price: $11.73    Subtotal: $11.73
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Cherry                         Qty: 2     Unit Price: $14.35    Subtotal: $28.70
# Product: Homemade bread                 Qty: 1     Unit Price: $17.48    Subtotal: $17.48
# Product: Smoothie with chia seeds       Qty: 1     Unit Price: $25.26    Subtotal: $25.26
# Product: Corn                           Qty: 1     Unit Price: $13.55    Subtotal: $13.55
# Product: Peaches on branch              Qty: 2     Unit Price: $25.62    Subtotal: $51.24
# Product: Pesto with basil               Qty: 2     Unit Price: $18.19    Subtotal: $36.38
# Product: Plums                          Qty: 1     Unit Price: $19.18    Subtotal: $19.18
# Product: Fresh blueberries              Qty: 2     Unit Price: $21.01    Subtotal: $42.02
# Product: Green smoothie                 Qty: 4     Unit Price: $17.68    Subtotal: $70.72
# Product: Corn                           Qty: 1     Unit Price: $13.55    Subtotal: $13.55
# Product: French fries                   Qty: 2     Unit Price: $18.32    Subtotal: $36.64
# Product: Ground beef meat burger        Qty: 3     Unit Price: $11.73    Subtotal: $35.19
# Product: Hazelnut in black ceramic bowl Qty: 1     Unit Price: $27.35    Subtotal: $27.35
# Product: Cherry                         Qty: 2     Unit Price: $14.35    Subtotal: $28.70
# Product: Homemade bread                 Qty: 5     Unit Price: $17.48    Subtotal: $87.40
# Product: Smoothie with chia seeds       Qty: 2     Unit Price: $25.26    Subtotal: $50.52
# Product: Corn                           Qty: 10    Unit Price: $13.55    Subtotal: $135.50
# Product: Rustic breakfast               Qty: 2     Unit Price: $21.32    Subtotal: $42.64
# Product: Sandwich with salad            Qty: 3     Unit Price: $22.48    Subtotal: $67.44
# Product: Raw legums                     Qty: 20    Unit Price: $17.11    Subtotal: $342.20
# Product: Fresh stawberry                Qty: 4     Unit Price: $28.59    Subtotal: $114.36
# Product: Pears juice                    Qty: 1     Unit Price: $19.49    Subtotal: $19.49
# Product: Green smoothie                 Qty: 8     Unit Price: $17.68    Subtotal: $141.44
# Product: Cuban sandwiche                Qty: 9     Unit Price: $18.50    Subtotal: $166.50
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Tomatoes                       Qty: 1     Unit Price: $26.03    Subtotal: $26.03
# Product: Plums                          Qty: 2     Unit Price: $19.18    Subtotal: $38.36
# Product: Fresh blueberries              Qty: 3     Unit Price: $21.01    Subtotal: $63.03
# Product: Green smoothie                 Qty: 5     Unit Price: $17.68    Subtotal: $88.40
# Product: Corn                           Qty: 4     Unit Price: $13.55    Subtotal: $54.20
#
# TOTAL COMPANY SALES: $2481.86
# Execution Time (seconds): 0.000470

# %% [markdown]
# ## Cálculo de ventas (archivo): TC2.Sales.json

# %%
# !python computeSales.py TC1.ProductList.json TC2.Sales.json
# Out:
# Warning: Negative quantity ignored: {'SALE_ID': 8, 'SALE_Date': '02/12/23', 'Product': 'Fresh blueberries', 'Quantity': -35}
# Warning: Negative quantity ignored: {'SALE_ID': 10, 'SALE_Date': '02/12/23', 'Product': 'Green smoothie', 'Quantity': -123}
# ==== COMPANY SALES REPORT ====
#
# Product: Rustic breakfast               Qty: 200   Unit Price: $21.32    Subtotal: $4264.00
# Product: Sandwich with salad            Qty: 23    Unit Price: $22.48    Subtotal: $517.04
# Product: Raw legums                     Qty: 11    Unit Price: $17.11    Subtotal: $188.21
# Product: Fresh stawberry                Qty: 221   Unit Price: $28.59    Subtotal: $6318.39
# Product: Raw legums                     Qty: 2     Unit Price: $17.11    Subtotal: $34.22
# Product: Green smoothie                 Qty: 400   Unit Price: $17.68    Subtotal: $7072.00
# Product: Cuban sandwiche                Qty: 2     Unit Price: $18.50    Subtotal: $37.00
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Tomatoes                       Qty: 1     Unit Price: $26.03    Subtotal: $26.03
# Product: Plums                          Qty: 250   Unit Price: $19.18    Subtotal: $4795.00
# Product: Fresh blueberries              Qty: 334   Unit Price: $21.01    Subtotal: $7017.34
# Product: Green smoothie                 Qty: 300   Unit Price: $17.68    Subtotal: $5304.00
# Product: Corn                           Qty: 68    Unit Price: $13.55    Subtotal: $921.40
# Product: French fries                   Qty: 33    Unit Price: $18.32    Subtotal: $604.56
# Product: Ground beef meat burger        Qty: 78    Unit Price: $11.73    Subtotal: $914.94
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Sweet fresh stawberry          Qty: 87    Unit Price: $29.45    Subtotal: $2562.15
# Product: Homemade bread                 Qty: 1     Unit Price: $17.48    Subtotal: $17.48
# Product: Smoothie with chia seeds       Qty: 46    Unit Price: $25.26    Subtotal: $1161.96
# Product: Corn                           Qty: 1     Unit Price: $13.55    Subtotal: $13.55
# Product: Plums                          Qty: 2     Unit Price: $19.18    Subtotal: $38.36
# Product: Fresh blueberries              Qty: 46    Unit Price: $21.01    Subtotal: $966.46
# Product: Green smoothie                 Qty: 1     Unit Price: $17.68    Subtotal: $17.68
# Product: Corn                           Qty: 2     Unit Price: $13.55    Subtotal: $27.10
# Product: French fries                   Qty: 4     Unit Price: $18.32    Subtotal: $73.28
# Product: Ground beef meat burger        Qty: 64    Unit Price: $11.73    Subtotal: $750.72
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Sweet fresh stawberry          Qty: 3     Unit Price: $29.45    Subtotal: $88.35
# Product: Homemade bread                 Qty: 456   Unit Price: $17.48    Subtotal: $7970.88
# Product: Smoothie with chia seeds       Qty: 2     Unit Price: $25.26    Subtotal: $50.52
# Product: Corn                           Qty: 5     Unit Price: $13.55    Subtotal: $67.75
# Product: Plums                          Qty: 645   Unit Price: $19.18    Subtotal: $12371.10
# Product: Green smoothie                 Qty: 2     Unit Price: $17.68    Subtotal: $35.36
# Product: Corn                           Qty: 465   Unit Price: $13.55    Subtotal: $6300.75
# Product: French fries                   Qty: 20    Unit Price: $18.32    Subtotal: $366.40
# Product: Ground beef meat burger        Qty: 4     Unit Price: $11.73    Subtotal: $46.92
# Product: Hazelnut in black ceramic bowl Qty: 1     Unit Price: $27.35    Subtotal: $27.35
# Product: Sweet fresh stawberry          Qty: 131   Unit Price: $29.45    Subtotal: $3857.95
# Product: Homemade bread                 Qty: 9     Unit Price: $17.48    Subtotal: $157.32
# Product: Smoothie with chia seeds       Qty: 13    Unit Price: $25.26    Subtotal: $328.38
# Product: Corn                           Qty: 678   Unit Price: $13.55    Subtotal: $9186.90
# Product: Plums                          Qty: 334   Unit Price: $19.18    Subtotal: $6406.12
# Product: Fresh blueberries              Qty: 3445  Unit Price: $21.01    Subtotal: $72379.45
# Product: Corn                           Qty: 445   Unit Price: $13.55    Subtotal: $6029.75
#
# TOTAL COMPANY SALES: $169478.22
# Execution Time (seconds): 0.000556

# %% [markdown]
# ## Cálculo de ventas (archivo): TC3.Sales.json

# %%
# !python computeSales.py TC1.ProductList.json TC3.Sales.json
# Out:
# Warning: Product 'Elotes' not found in catalogue.
# Warning: Negative quantity ignored: {'SALE_ID': 8, 'SALE_Date': '02/12/23', 'Product': 'Fresh blueberries', 'Quantity': -35}
# Warning: Product 'Frijoles' not found in catalogue.
# Warning: Negative quantity ignored: {'SALE_ID': 10, 'SALE_Date': '02/12/23', 'Product': 'Green smoothie', 'Quantity': -123}
# ==== COMPANY SALES REPORT ====
#
# Product: Rustic breakfast               Qty: 200   Unit Price: $21.32    Subtotal: $4264.00
# Product: Sandwich with salad            Qty: 23    Unit Price: $22.48    Subtotal: $517.04
# Product: Raw legums                     Qty: 11    Unit Price: $17.11    Subtotal: $188.21
# Product: Fresh stawberry                Qty: 221   Unit Price: $28.59    Subtotal: $6318.39
# Product: Raw legums                     Qty: 2     Unit Price: $17.11    Subtotal: $34.22
# Product: Green smoothie                 Qty: 400   Unit Price: $17.68    Subtotal: $7072.00
# Product: Cuban sandwiche                Qty: 2     Unit Price: $18.50    Subtotal: $37.00
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Tomatoes                       Qty: 1     Unit Price: $26.03    Subtotal: $26.03
# Product: Plums                          Qty: 250   Unit Price: $19.18    Subtotal: $4795.00
# Product: Fresh blueberries              Qty: 334   Unit Price: $21.01    Subtotal: $7017.34
# Product: Green smoothie                 Qty: 300   Unit Price: $17.68    Subtotal: $5304.00
# Product: Corn                           Qty: 68    Unit Price: $13.55    Subtotal: $921.40
# Product: French fries                   Qty: 33    Unit Price: $18.32    Subtotal: $604.56
# Product: Ground beef meat burger        Qty: 78    Unit Price: $11.73    Subtotal: $914.94
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Sweet fresh stawberry          Qty: 87    Unit Price: $29.45    Subtotal: $2562.15
# Product: Homemade bread                 Qty: 1     Unit Price: $17.48    Subtotal: $17.48
# Product: Smoothie with chia seeds       Qty: 46    Unit Price: $25.26    Subtotal: $1161.96
# Product: Corn                           Qty: 1     Unit Price: $13.55    Subtotal: $13.55
# Product: Plums                          Qty: 2     Unit Price: $19.18    Subtotal: $38.36
# Product: Green smoothie                 Qty: 1     Unit Price: $17.68    Subtotal: $17.68
# Product: Corn                           Qty: 2     Unit Price: $13.55    Subtotal: $27.10
# Product: French fries                   Qty: 4     Unit Price: $18.32    Subtotal: $73.28
# Product: Ground beef meat burger        Qty: 64    Unit Price: $11.73    Subtotal: $750.72
# Product: Hazelnut in black ceramic bowl Qty: 2     Unit Price: $27.35    Subtotal: $54.70
# Product: Sweet fresh stawberry          Qty: 3     Unit Price: $29.45    Subtotal: $88.35
# Product: Homemade bread                 Qty: 456   Unit Price: $17.48    Subtotal: $7970.88
# Product: Smoothie with chia seeds       Qty: 2     Unit Price: $25.26    Subtotal: $50.52
# Product: Corn                           Qty: 5     Unit Price: $13.55    Subtotal: $67.75
# Product: Plums                          Qty: 645   Unit Price: $19.18    Subtotal: $12371.10
# Product: Green smoothie                 Qty: 2     Unit Price: $17.68    Subtotal: $35.36
# Product: Corn                           Qty: 465   Unit Price: $13.55    Subtotal: $6300.75
# Product: Ground beef meat burger        Qty: 4     Unit Price: $11.73    Subtotal: $46.92
# Product: Hazelnut in black ceramic bowl Qty: 1     Unit Price: $27.35    Subtotal: $27.35
# Product: Sweet fresh stawberry          Qty: 131   Unit Price: $29.45    Subtotal: $3857.95
# Product: Homemade bread                 Qty: 9     Unit Price: $17.48    Subtotal: $157.32
# Product: Smoothie with chia seeds       Qty: 13    Unit Price: $25.26    Subtotal: $328.38
# Product: Corn                           Qty: 678   Unit Price: $13.55    Subtotal: $9186.90
# Product: Plums                          Qty: 334   Unit Price: $19.18    Subtotal: $6406.12
# Product: Fresh blueberries              Qty: 3445  Unit Price: $21.01    Subtotal: $72379.45
# Product: Corn                           Qty: 445   Unit Price: $13.55    Subtotal: $6029.75
#
# TOTAL COMPANY SALES: $168145.36
# Execution Time (seconds): 0.000802

# %% [markdown]
# # Instalación de Pylint

# %%
pip install pylint
# Out:
# Requirement already satisfied: pylint in /usr/local/lib/python3.12/dist-packages (4.0.4)
# Requirement already satisfied: astroid<=4.1.dev0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from pylint) (4.0.4)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.12/dist-packages (from pylint) (0.3.8)
# Requirement already satisfied: isort!=5.13,<8,>=5 in /usr/local/lib/python3.12/dist-packages (from pylint) (7.0.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from pylint) (0.7.0)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.12/dist-packages (from pylint) (4.5.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from pylint) (0.13.3)

# %% [markdown]
# #Análisis del Código con Pylint

# %%
# !pylint computeSales.py
# Out:
# ************* Module computeSales
# computeSales.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# computeSales.py:23:0: C0303: Trailing whitespace (trailing-whitespace)
# computeSales.py:38:0: C0303: Trailing whitespace (trailing-whitespace)
# computeSales.py:73:0: C0303: Trailing whitespace (trailing-whitespace)
# computeSales.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# computeSales.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# computeSales.py:1:0: C0103: Module name "computeSales" doesn't conform to snake_case naming style (invalid-name)
# computeSales.py:9:0: C0116: Missing function or method docstring (missing-function-docstring)
# computeSales.py:22:0: C0116: Missing function or method docstring (missing-function-docstring)
# computeSales.py:37:0: C0116: Missing function or method docstring (missing-function-docstring)
# computeSales.py:72:0: C0116: Missing function or method docstring (missing-function-docstring)
# computeSales.py:79:0: C0116: Missing function or method docstring (missing-function-docstring)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.38/10 (previous run: 9.59/10, -1.22)

# %% [markdown]
# # Instalación de Flake

# %%
pip install flake8
# Out:
# Requirement already satisfied: flake8 in /usr/local/lib/python3.12/dist-packages (7.3.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from flake8) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from flake8) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from flake8) (3.4.0)

# %% [markdown]
# # Análisis de Código con Flake

# %%
# !flake8 computeSales.py
# Out:
# computeSales.py:4:1: E303 too many blank lines (3)
# computeSales.py:10:1: W293 blank line contains whitespace
# computeSales.py:23:1: W293 blank line contains whitespace
# computeSales.py:38:1: W293 blank line contains whitespace
# computeSales.py:73:1: W293 blank line contains whitespace
# computeSales.py:80:1: W293 blank line contains whitespace

# %% [markdown]
# #Conclusiones
